# %% [markdown]
# # SUV Analyse Schweiz

# %%
import pandas as pd
import numpy as np
import os
import re
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Daten importieren

# %% [markdown]
# ### Import Mockup Data
# Daten sind auf 10000 zufällige Einträge reduziert. Aus Datenschutzgründen sind zusätzlich die die folgenden Spalten mit Platzhaltern Versehen:
# - Erstinvekehrsetzung_Kanton
# - Inverkehrsetzung_Kanton
# - PLZ
# - Ort
#
# Bei der Spalte BFS-Gemeinde-Nr ist eine zufällige (valide) BFS Nummer angegeben.

# %%
## read astra data
df_input = pd.read_csv("Mockup_Data.csv", encoding = 'utf-8')

# reduce to Personenwagen
df = df_input.loc[df_input.Fahrzeugart == "Personenwagen"]

#a = df.sample(1000)
#a = df_res_raw.sample(1000)
#aa = df_res_raw.sort_index().head(1000)
#aaa = df.head(4000)
#sum(df_res_raw.index.duplicated(keep = False))
#aaaa = df_res_raw.loc[df_res_raw.index.duplicated(keep = False), :].sort_index()


# make all strings lowercasye
df.loc[:, 'Marke'] = df.loc[:, 'Marke'].astype(str).str.lower()
df.loc[:, 'Marke_und_Typ'] = df.loc[:, 'Marke_und_Typ'].astype(str).str.lower()
df.loc[:, 'Typ1'] = df.loc[:, 'Typ1'].astype(str).str.lower()
df.loc[:, 'Typ2'] = df.loc[:, 'Typ2'].astype(str).str.lower()
df.loc[:, 'Typ3'] = df.loc[:, 'Typ3'].astype(str).str.lower()

df.head(5)
# Out:
#    Unnamed: 0 Fahrzeugklasse  Fahrzeugart_Code    Fahrzeugart  Marken_Code  \
# 0     4717617             M1                 1  Personenwagen         6306
# 1     5424362             M1                 1  Personenwagen         5100
# 2     6269855             M1                 1  Personenwagen         4017
# 3     1365562             M1                 1  Personenwagen         3019
# 4      198970             M1                 1  Personenwagen         4009
#
#     Marke         Marke_und_Typ             Typ1     Typ2    Typ3  \
# 0   skoda     skoda yeti 1.2tsi      yeti 1.2tsi     yeti  1.2tsi
# 1  toyota    toyota corolla 1.6      corolla 1.6  corolla     1.6
# 2      vw      vw sharan 2.0d 7    sharan 2.0d 7   sharan    2.0d
# 3    fiat     fiat punto 1.4 8v     punto 1.4 8v    punto     1.4
# 4    audi  audi a4 av. qu. 2.0t  a4 av. qu. 2.0t       a4     av.
#
#       ...       PLZ       Ort BFS-Gemeinde-Nr  Staat_Code    Staat  \
# 0     ...       PLZ  Gemeinde            6235          CH  Schweiz
# 1     ...       PLZ  Gemeinde             141          CH  Schweiz
# 2     ...       PLZ  Gemeinde             198          CH  Schweiz
# 3     ...       PLZ  Gemeinde            2773          CH  Schweiz
# 4     ...       PLZ  Gemeinde            3255          CH  Schweiz
#
#   Halterart_Code   Halterart  Besondere_Verwendung_Code  Besondere_Verwendung  \
# 0              1    männlich                        NaN                   NaN
# 1              1    männlich                        NaN                   NaN
# 2              3  juristisch                        NaN                   NaN
# 3              2    weiblich                        NaN                   NaN
# 4              2    weiblich                        NaN                   NaN
#
#    Unnamed: 63
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# ### Typenliste wird eingelesen

# %%
## read Typenliste
df_typen_input = pd.read_csv("Data_input/Typenliste SUV - export.csv", encoding = 'utf-8')
df_typen_input.columns
df_typen = df_typen_input.loc[df_typen_input.entfernen == "Nein"]

# make all strings lovercase
df_typen.loc[:, 'Marke'] = df_typen.loc[:, 'Marke'].astype(str).str.lower()
df_typen.loc[:, 'Typ'] = df_typen.loc[:, 'Typ'].astype(str).str.lower()

# define different searchtypes dfs
df_typen_alle = df_typen.loc[df_typen.such_typ == "alle"]
df_typen_normal = df_typen.loc[df_typen.such_typ == "normal"]
df_typen_exakt = df_typen.loc[df_typen.such_typ == "exakt"]

df_typen.head(5)
# Out:
#         Marke      Typ entfernen such_typ  original_typ  Lux
# 0      hummer        -      Nein     alle  Alle Modelle  lux
# 3  alfa romeo  stelvio      Nein   normal       STELVIO  lux
# 4        audi       q2      Nein   normal            Q2    x
# 5         bmw       x1      Nein   normal            X1    x
# 6         bmw       x4      Nein   normal            X4  lux

# %% [markdown]
# ### Bevölkerungsdaten einlesen

# %%
## read Population data
df_pop = pd.read_csv("Data_input/Bevoelkerung_2018_export.csv", encoding = 'utf-8')

df_pop.head(5)
# Out:
#    BFS-Gemeinde-Nr             Ort_BfS  Bevölkerung
# 0                1     Aeugst am Albis         1982
# 1                2  Affoltern am Albis        12229
# 2                3          Bonstetten         5548
# 3                4     Hausen am Albis         3701
# 4                5            Hedingen         3734

# %% [markdown]
# ## Typen zuordnen
# Aus allen Personenwagen werden die SUVs gemäss der vorgegebenen Liste herausgesucht.

# %%
## all Hummers
df_res_all = pd.DataFrame()
for i, row in df_typen_alle.iterrows():
    print(row.Marke)
    marke = row.Marke
    index = [marke in x for x in list(df.Marke)]
    if(sum(index) != 0):
        res_temp = df.loc[index]
        res_temp.loc[:, 'Marke_harm'] = marke
        res_temp.loc[:, 'Type_harm'] = row.original_typ
        res_temp.loc[:, 'Luxury'] = row.Lux
        df_res_all = pd.concat([df_res_all, res_temp])

# normal cases (marke + typ)
df_res_normal = pd.DataFrame()
for marke in df_typen_normal.Marke.unique():
    temp_marke = df[[marke in x for x in list(df.Marke)]]
    df_typen_normal_marken = df_typen_normal[df_typen_normal.Marke == marke]
    print(marke + ": " + str(len(temp_marke)))

    for i, row in df_typen_normal_marken.iterrows():
        typ = row.Typ
        index = [typ in x for x in list(temp_marke.Marke_und_Typ)]
        if(sum(index) != 0):
            res_temp = temp_marke.loc[index]
            res_temp.loc[:, 'Marke_harm'] = row.Marke
            res_temp.loc[:, 'Type_harm'] = row.original_typ
            res_temp.loc[:, 'Luxury'] = row.Lux
            df_res_normal = pd.concat([df_res_normal, res_temp])
            print("   " + row.Typ + ": " + str(len(res_temp)))
            
## exakt cases (marke + typ)

df_res_exakt = pd.DataFrame()
for marke in df_typen_exakt.Marke.unique():
    temp_marke = df[[marke in x for x in list(df.Marke)]]
    df_typen_exakt_marken = df_typen_exakt[df_typen_exakt.Marke == marke]
    print(marke + ": " + str(len(temp_marke)))
        
    for i, row in df_typen_exakt_marken.iterrows():
        typ = row.Typ
        index_is = [(re.search(r"\b%s{1}\b" % typ, x) is not None) for x in list(temp_marke.Marke_und_Typ)]
        index_not1 = [(re.search(r"\b%s{1}\b" % "gt", x) is not None) for x in list(temp_marke.Marke_und_Typ)]
         # GT R nicht berücksichtigen!
        index = index_is & np.invert(index_not1)

        if(sum(index) != 0):
            res_temp = temp_marke.loc[index]
            res_temp.loc[:, 'Marke_harm'] = marke
            res_temp.loc[:, 'Type_harm'] = df_typen_exakt_marken.loc[i, 'original_typ']
            res_temp.loc[:, 'Luxury'] = row.Lux
            df_res_exakt = pd.concat([df_res_exakt, res_temp])
            print("   " + typ + ": " + str(len(res_temp)))
        
        
## concat
df_res_raw = pd.concat([df_res_all, df_res_normal, df_res_exakt])
# Out:
# hummer
# alfa romeo: 73
#    stelvio: 3
# audi: 477
#    q2: 10
#    q3: 24
#    q5: 49
#    q7: 13
# bmw: 461
#    x1: 37
#    x4: 7
#    x3: 57
#    x5: 29
#    x6: 6
# chevrolet: 48
#    captiva: 5
#    trax: 2
# citroen: 225
#    crosser: 5
#    cactus: 6
# dacia: 76
#    duster: 17
# daihatsu: 27
#    terios: 12
#    feroza: 1
# fiat: 220
#    sedici: 4
# ford: 371
#    ecosport: 6
#    edge: 3
#    kuga: 60
#    maverick: 2
# honda: 150
#    cr-v: 30
#    hr-v: 3
# hyundai: 162
#    35: 20
#    55: 1
#    kona: 4
#    tucson: 13
#    santa: 17
#    terracan: 1
# infiniti: 4
# kia: 64
#    niro: 1
#    sportage: 11
#    sorento: 8
# lada: 0
# lexus: 18
#    rx: 4
# mazda: 165
#    cx-3: 8
#    cx-5: 19
#    cx-7: 3
# mitsubishi: 97
#    asx: 13
#    outlander: 14
#    pajero: 11
# nissan: 164
#    murano: 1
#    qashqai: 55
#    pathfinder: 5
#    patrol: 2
#    trail: 9
# opel: 381
#    antara: 7
#    crossland: 5
#    grandland: 5
#    mokka: 18
#    frontera: 1
# peugeot: 275
#    2008: 13
#    4007: 2
#    4008: 4
# renault: 333
#    captur: 19
#    kadjar: 8
#    koleos: 10
# seat: 205
#    ateca: 15
# skoda: 328
#    karoq: 5
#    yeti: 25
#    kodiaq: 7
# ssangyong: 7
#    korando: 3
#    rexton: 4
# subaru: 176
#    xv: 22
#    forester: 49
# suzuki: 134
#    sx4: 31
#    vitara: 24
#    jimny: 6
# tesla: 8
#    x: 3
# toyota: 374
#    c-hr: 2
#    rav 4: 2
#    landcruiser: 5
# volvo: 159
#    xc70: 5
#    xc60: 35
#    xc90: 13
# vw: 963
#    t-roc: 13
#    tiguan: 82
#    touareg: 22
# cadillac: 4
#    srx: 2
# dodge: 9
#    nitro: 2
# jaguar: 29
#    f-pace: 1
# jeep: 63
#    cherokee: 34
#    compass: 11
#    patriot: 1
#    renegade: 9
#    wrangler: 7
# land rover: 51
#    defender: 2
#    discovery: 10
#    freelander: 6
#    range rover: 3
# porsche: 67
#    cayenne: 12
#    macan: 10
# lamborghini: 0
# maserati: 9
#    levante: 4
# royce: 1
# mercedes: 453
#    gla: 17
#    glk: 7
#    glc: 24
#    g: 2
#    gl: 1
#    gle: 10

# %% [markdown]
# ### Duplikate entfernen
# 4893              glc             250          ...            Schweiz
# 4927              glc            250d          ...            Schweiz
# 5822              glc             250          ...            Schweiz
# 6297              glc             300          ...            Schweiz
# 6304              glc            250d          ...            Schweiz
# 6615              glc            250d          ...            Schweiz
# 7550              glc            250d          ...            Schweiz
# 7926              glc            250d          ...            Schweiz
# 8237              glc            220d          ...            Schweiz
# 8558              glc            250d          ...            Schweiz
# 8842              glc            250d          ...            Schweiz
# 9786              glc            250d          ...            Schweiz
# 2595              amg               g          ...            Schweiz
# 6361                g             500          ...            Schweiz
# 5749               gl             500          ...            Schweiz
# 256               gle            350d          ...            Schweiz
# 447               gle             250          ...            Schweiz
# 4169              gle             350          ...            Schweiz
# 4463              gle             450          ...            Schweiz
# 5671              gle             350          ...            Schweiz
# 5804              gle             400          ...            Schweiz
# 5956              amg             gle          ...            Schweiz
# 7826              gle             350          ...            Schweiz
# 8676              gle             350          ...            Schweiz
# 8781              gle             350          ...            Schweiz
#
#      Halterart_Code   Halterart  Besondere_Verwendung_Code  \
# 792               1    männlich                        NaN
# 258               3  juristisch                        NaN
# 4106              1    männlich                        NaN
# 8945              1    männlich                        NaN
# 2888              1    männlich                        NaN
# 5330              1    männlich                        NaN
# 6642              2    weiblich                        NaN
# 7460              1    männlich                        NaN
# 8683              2    weiblich                        NaN
# 9128              3  juristisch                        NaN
# 9141              1    männlich                        NaN
# 9663              3  juristisch                        NaN
# 9678              1    männlich                        NaN
# 9918              1    männlich                        NaN
# 265               2    weiblich                        NaN
# 395               1    männlich                        NaN
# 474               1    männlich                        NaN
# 926               1    männlich                        NaN
# 1810              3  juristisch                        NaN
# 2015              1    männlich                        NaN
# 2105              2    weiblich                        NaN
# 3373              3  juristisch                        NaN
# 3405              1    männlich                        NaN
# 5166              2    weiblich                        NaN
# 5219              1    männlich                        NaN
# 5766              3  juristisch                        NaN
# 5922              1    männlich                        NaN
# 6878              2    weiblich                        NaN
# 7385              1    männlich                        NaN
# 7563              2    weiblich                        NaN
# ...             ...         ...                        ...
# 3751              1    männlich                        NaN
# 4151              1    männlich                        NaN
# 4595              2    weiblich                        NaN
# 4599              3  juristisch                        NaN
# 4737              1    männlich                        NaN
# 4893              1    männlich                        NaN
# 4927              3  juristisch                        NaN
# 5822              1    männlich                        NaN
# 6297              1    männlich                        NaN
# 6304              1    männlich                        NaN
# 6615              3  juristisch                        NaN
# 7550              1    männlich                        NaN
# 7926              1    männlich                        NaN
# 8237              1    männlich                        NaN
# 8558              2    weiblich                        NaN
# 8842              1    männlich                        NaN
# 9786              1    männlich                        NaN
# 2595              1    männlich                        NaN
# 6361              3  juristisch                        NaN
# 5749              1    männlich                        NaN
# 256               1    männlich                        NaN
# 447               1    männlich                        NaN
# 4169              3  juristisch                        NaN
# 4463              1    männlich                        NaN
# 5671              3  juristisch                        NaN
# 5804              3  juristisch                        NaN
# 5956              2    weiblich                        NaN
# 7826              3  juristisch                        NaN
# 8676              2    weiblich                        NaN
# 8781              3  juristisch                        NaN
#
#      Besondere_Verwendung Unnamed: 63  Marke_harm     Type_harm  Luxury  \
# 792                   NaN         NaN      hummer  Alle Modelle     lux
# 258                   NaN         NaN  alfa romeo       STELVIO     lux
# 4106                  NaN         NaN  alfa romeo       STELVIO     lux
# 8945                  NaN         NaN  alfa romeo       STELVIO     lux
# 2888                  NaN         NaN        audi            Q2       x
# 5330                  NaN         NaN        audi            Q2       x
# 6642                  NaN         NaN        audi            Q2       x
# 7460                  NaN         NaN        audi            Q2       x
# 8683                  NaN         NaN        audi            Q2       x
# 9128                  NaN         NaN        audi            Q2       x
# 9141                  NaN         NaN        audi            Q2       x
# 9663                  NaN         NaN        audi            Q2       x
# 9678                  NaN         NaN        audi            Q2       x
# 9918                  NaN         NaN        audi            Q2       x
# 265                   NaN         NaN        audi            Q3       x
# 395                   NaN         NaN        audi            Q3       x
# 474                   NaN         NaN        audi            Q3       x
# 926                   NaN         NaN        audi            Q3       x
# 1810                  NaN         NaN        audi            Q3       x
# 2015                  NaN         NaN        audi            Q3       x
# 2105                  NaN         NaN        audi            Q3       x
# 3373                  NaN         NaN        audi            Q3       x
# 3405                  NaN         NaN        audi            Q3       x
# 5166                  NaN         NaN        audi            Q3       x
# 5219                  NaN         NaN        audi            Q3       x
# 5766                  NaN         NaN        audi            Q3       x
# 5922                  NaN         NaN        audi            Q3       x
# 6878                  NaN         NaN        audi            Q3       x
# 7385                  NaN         NaN        audi            Q3       x
# 7563                  NaN         NaN        audi            Q3       x
# ...                   ...         ...         ...           ...     ...
# 3751                  NaN         NaN    mercedes           GLC     lux
# 4151                  NaN         NaN    mercedes           GLC     lux
# 4595                  NaN         NaN    mercedes           GLC     lux
# 4599                  NaN         NaN    mercedes           GLC     lux
# 4737                  NaN         NaN    mercedes           GLC     lux
# 4893                  NaN         NaN    mercedes           GLC     lux
# 4927                  NaN         NaN    mercedes           GLC     lux
# 5822                  NaN         NaN    mercedes           GLC     lux
# 6297                  NaN         NaN    mercedes           GLC     lux
# 6304                  NaN         NaN    mercedes           GLC     lux
# 6615                  NaN         NaN    mercedes           GLC     lux
# 7550                  NaN         NaN    mercedes           GLC     lux
# 7926                  NaN         NaN    mercedes           GLC     lux
# 8237                  NaN         NaN    mercedes           GLC     lux
# 8558                  NaN         NaN    mercedes           GLC     lux
# 8842                  NaN         NaN    mercedes           GLC     lux
# 9786                  NaN         NaN    mercedes           GLC     lux
# 2595                  NaN         NaN    mercedes      G-KLASSE     lux
# 6361                  NaN         NaN    mercedes      G-KLASSE     lux
# 5749                  NaN         NaN    mercedes            GL     lux
# 256                   NaN         NaN    mercedes           GLE     lux
# 447                   NaN         NaN    mercedes           GLE     lux
# 4169                  NaN         NaN    mercedes           GLE     lux
# 4463                  NaN         NaN    mercedes           GLE     lux
# 5671                  NaN         NaN    mercedes           GLE     lux
# 5804                  NaN         NaN    mercedes           GLE     lux
# 5956                  NaN         NaN    mercedes           GLE     lux
# 7826                  NaN         NaN    mercedes           GLE     lux
# 8676                  NaN         NaN    mercedes           GLE     lux
# 8781                  NaN         NaN    mercedes           GLE     lux
#
#              Marke_Typ_harm
# 792   hummer - Alle Modelle
# 258    alfa romeo - STELVIO
# 4106   alfa romeo - STELVIO
# 8945   alfa romeo - STELVIO
# 2888              audi - Q2
# 5330              audi - Q2
# 6642              audi - Q2
# 7460              audi - Q2
# 8683              audi - Q2
# 9128              audi - Q2
# 9141              audi - Q2
# 9663              audi - Q2
# 9678              audi - Q2
# 9918              audi - Q2
# 265               audi - Q3
# 395               audi - Q3
# 474               audi - Q3
# 926               audi - Q3
# 1810              audi - Q3
# 2015              audi - Q3
# 2105              audi - Q3
# 3373              audi - Q3
# 3405              audi - Q3
# 5166              audi - Q3
# 5219              audi - Q3
# 5766              audi - Q3
# 5922              audi - Q3
# 6878              audi - Q3
# 7385              audi - Q3
# 7563              audi - Q3
# ...                     ...
# 3751         mercedes - GLC
# 4151         mercedes - GLC
# 4595         mercedes - GLC
# 4599         mercedes - GLC
# 4737         mercedes - GLC
# 4893         mercedes - GLC
# 4927         mercedes - GLC
# 5822         mercedes - GLC
# 6297         mercedes - GLC
# 6304         mercedes - GLC
# 6615         mercedes - GLC
# 7550         mercedes - GLC
# 7926         mercedes - GLC
# 8237         mercedes - GLC
# 8558         mercedes - GLC
# 8842         mercedes - GLC
# 9786         mercedes - GLC
# 2595    mercedes - G-KLASSE
# 6361    mercedes - G-KLASSE
# 5749          mercedes - GL
# 256          mercedes - GLE
# 447          mercedes - GLE
# 4169         mercedes - GLE
# 4463         mercedes - GLE
# 5671         mercedes - GLE
# 5804         mercedes - GLE
# 5956         mercedes - GLE
# 7826         mercedes - GLE
# 8676         mercedes - GLE
# 8781         mercedes - GLE
#
# [1252 rows x 69 columns]

# %%
# store results
df_res.to_csv("res_mockup_29_11_2019.csv")

# %% [markdown]
# ## Analyse

# %% [markdown]
# ### SUVs pro Gemeinde zählen

# %%
## Group by Municipality

df_res_CH = df_res.loc[df_res.Staat_Code == "CH"]

counts_SUV = pd.DataFrame(df_res_CH.loc[:, 'BFS-Gemeinde-Nr'].value_counts())
counts_SUV.rename(columns={'BFS-Gemeinde-Nr':'Anzahl_SUV'}, inplace=True)
counts_SUV.loc[:, 'BFS-Gemeinde-Nr'] = counts_SUV.index

counts_SUV.head(5)
# Out:
#       Anzahl_SUV  BFS-Gemeinde-Nr
# 261           25              261
# 3203          19             3203
# 351           16              351
# 1061          14             1061
# 230           13              230

# %% [markdown]
# ### Luxuriöse SUVs pro Gemeinde zählen

# %%
# add number of Luxury SUV
df_res_lux = df_res.loc[df_res.Luxury == "lux", :]
counts_luxSUV = pd.DataFrame(df_res_lux.loc[:, 'BFS-Gemeinde-Nr'].value_counts())
counts_luxSUV.rename(columns={'BFS-Gemeinde-Nr':'Anzahl_luxSUV'}, inplace=True)
counts_luxSUV.loc[:, 'BFS-Gemeinde-Nr'] = counts_luxSUV.index

counts_luxSUV.head(5)
# Out:
#       Anzahl_luxSUV  BFS-Gemeinde-Nr
# 261              10              261
# 3203              8             3203
# 6711              5             6711
# 230               5              230
# 3427              4             3427

# %% [markdown]
# ### Gesamtanzahl Autos pro Gemeinde zählen

# %%
# add number of total cars
df_CH = df.loc[df.Staat_Code == "CH"]
counts_alleautos = pd.DataFrame(df_CH.loc[:, 'BFS-Gemeinde-Nr'].value_counts())
counts_alleautos.rename(columns={'BFS-Gemeinde-Nr':'Anzahl_auto'}, inplace=True)
counts_alleautos.loc[:, 'BFS-Gemeinde-Nr'] = counts_alleautos.index


counts_alleautos.head(5)
# Out:
#       Anzahl_auto  BFS-Gemeinde-Nr
# 261           197              261
# 6621          108             6621
# 351            92              351
# 5586           74             5586
# 230            66              230

# %% [markdown]
# ### Zusammenführen mit Bevölkerungsdaten

# %%
# Join population
res_gemeinde = pd.merge(counts_SUV, df_pop, how = 'left')
res_gemeinde.loc[:, 'SUV_per_pop'] = res_gemeinde.Anzahl_SUV / res_gemeinde.Bevölkerung

# Join total number of cars
res_gemeinde = pd.merge(res_gemeinde, counts_alleautos, how = 'left')
res_gemeinde.loc[:, 'SUV_per_auto'] = res_gemeinde.Anzahl_SUV / res_gemeinde.Anzahl_auto

# Join number luxury SUV
res_gemeinde = pd.merge(res_gemeinde, counts_luxSUV, how = 'left')
res_gemeinde.loc[:, 'luxSUV_per_auto'] = res_gemeinde.Anzahl_luxSUV / res_gemeinde.Anzahl_auto
res_gemeinde.loc[:, 'luxSUV_per_pop'] = res_gemeinde.Anzahl_luxSUV / res_gemeinde.Bevölkerung

# remove Liechtenstein
res_gemeinde = res_gemeinde.loc[res_gemeinde.loc[:, 'BFS-Gemeinde-Nr'] < 7000, :]

# %% [markdown]
# ## Resultate
#
# Erinnerung: Diese Daten sind zufällig gemischt und zeigen nur einen kleinen Ausschnitt aus allen Daten (10'000 Einträge von ca. 4.5 Millionen)

# %% [markdown]
# ### Tabelle mit allen Gemeinden

# %%
res_gemeinde.head(5)
# Out:
#    Anzahl_SUV  BFS-Gemeinde-Nr     Ort_BfS  Bevölkerung  SUV_per_pop  \
# 0          25              261      Zürich     415367.0     0.000060
# 1          19             3203  St. Gallen      75833.0     0.000251
# 2          16              351        Bern     133883.0     0.000120
# 3          14             1061      Luzern      81691.0     0.000171
# 4          13              230  Winterthur     111851.0     0.000116
#
#    Anzahl_auto  SUV_per_auto  Anzahl_luxSUV  luxSUV_per_auto  luxSUV_per_pop
# 0          197      0.126904           10.0         0.050761        0.000024
# 1           55      0.345455            8.0         0.145455        0.000105
# 2           92      0.173913            3.0         0.032609        0.000022
# 3           59      0.237288            2.0         0.033898        0.000024
# 4           66      0.196970            5.0         0.075758        0.000045

# %% [markdown]
# ### Tabelle mit beliebtesten SUV Marken

# %%
counts_marke = df_res.Marke_harm.value_counts().sort_values(ascending = False)
counts_marke.head(5)
# Out:
# bmw       136
# vw        117
# audi       96
# nissan     72
# ford       71
# Name: Marke_harm, dtype: int64

# %% [markdown]
# ### Tabelle mit beliebtesten SUV Typen

# %%
counts_marke_type = df_res.Marke_Typ_harm.value_counts().sort_values(ascending = False)
counts_marke_type.head(5)
# Out:
# vw - TIGUAN         82
# ford - KUGA         60
# bmw - X3            57
# nissan - QASHQAI    55
# audi - Q5           49
# Name: Marke_Typ_harm, dtype: int64
